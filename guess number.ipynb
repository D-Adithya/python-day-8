# %%
from replit import clear

logo='''
                                                                           
                                                                    
 ,---. ,--.,--. ,---.  ,---.  ,---.                                  
| .-. ||  ||  || .-. :(  .-' (  .-'                                    
' '-' ''  ''  '\   --..-'  `).-'  `)                                  
.`-  /  `----'  `----'`----' `----'                                    
`---'                                                                   
  ,--.  ,--.                                          ,--.                  
,-'  '-.|  ,---.  ,---.     ,--,--, ,--.,--.,--,--,--.|  |-.  ,---. ,--.--. 
'-.  .-'|  .-.  || .-. :    |      \|  ||  ||        || .-. '| .-. :|  .--' 
  |  |  |  | |  |\   --.    |  ||  |'  ''  '|  |  |  || `-' |\   --.|  |    
  `--'  `--' `--' `----'    `--''--' `----' `--`--`--' `---'  `----'`--'    
                                                                            


'''
import random
numbers=random.randint(1,101)

def easy():
    attempts=10
    for i in range(10):
        choice=int(input("guess the number:"))
        if choice==numbers:
            print("your guess is right\n")
            break
        elif choice>numbers:
            print('your guess is too high!\n')
        elif choice<numbers:
            print('your guess is too low!\n')
        elif choice>100:
            print("game is guessinng number between 1 to 100")
        attempts=attempts-1
        if attempts==0:
            print("you lost you used every attempts")
            
        print("you have",attempts,"left to guess the number\n")
def hard():
    attempts=5
    for i in range(5):
        choice=int(input("guess the number:"))
        if choice==numbers:
            print("your guess is right the number was :\n",number)
            break
        elif choice>numbers:
            print('your guess is too high!\n')
        elif choice<numbers:
            print('your guess is too low!\n')
        elif choice>100:
            print("game is guessinng number between 1 to 100")
        attempts=attempts-1
        if attempts==0:
            print("you lost ! you used every attempts")
            print("the correct answer is :",numbers)
            break
        print("you have",attempts,"left to guess the number\n")
        
def guess_game():
    level=input("choose a difficulty! pick 'hard' or 'easy' :")
    if level=='hard':
        hard()
    elif level=='easy':
        easy()
    else:
        print(" type easy or hard! ")

end=True
while end==True :
    print(logo)
    print("welcome to the number guessing game!\n")
    print("I am guessing a number between 1 and 100\n")
    guess_game()
    again=input("\ndo you want to play again.type yes or no:\n")
    if again=="no":
        end=False
    clear()
# Out:
#
#
#  ,---. ,--.,--. ,---.  ,---.  ,---.
# | .-. ||  ||  || .-. :(  .-' (  .-'
# ' '-' ''  ''  '\   --..-'  `).-'  `)
# .`-  /  `----'  `----'`----' `----'
# `---'
#   ,--.  ,--.                                          ,--.
# ,-'  '-.|  ,---.  ,---.     ,--,--, ,--.,--.,--,--,--.|  |-.  ,---. ,--.--.
# '-.  .-'|  .-.  || .-. :    |      \|  ||  ||        || .-. '| .-. :|  .--'
#   |  |  |  | |  |\   --.    |  ||  |'  ''  '|  |  |  || `-' |\   --.|  |
#   `--'  `--' `--' `----'    `--''--' `----' `--`--`--' `---'  `----'`--'
#
#
#
#
# welcome to the number guessing game!
#
# I am guessing a number between 1 and 100
#
# choose a difficulty! pick 'hard' or 'easy' :hard
# guess the number:59
# your guess is too low!
#
# you have 4 left to guess the number
#
# guess the number:70
# your guess is too low!
#
# you have 3 left to guess the number
#
# guess the number:82
# your guess is too low!
#
# you have 2 left to guess the number
#
# guess the number:91
# your guess is too low!
#
# ...

# %%
pip install replit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
